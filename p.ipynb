# %%
from matplotlib import pyplot as plt
import matplotlib

font = { 'family' : 'SimSun',
        'weight' : 'bold',
         'size'   : '20'}
matplotlib.rc('font',**font)

# %%
import pandas as pd

# %%
my_data = pd.read_csv('样例\城市数据_加盐.csv',encoding='utf-8')

# %%
cty = my_data['cty_cd'].value_counts()/my_data['cty_cd'].value_counts().sum()

# %%
cty.plot(kind = 'pie', autopct = '%.2f%%',
                figsize = (7, 7), title = '城市',
                label = '')
# Out:
# <AxesSubplot:title={'center':'城市'}>

# %%
 my_data.isna()
# Out:
#      Unnamed: 0  year_id  month_id  cty_cd    旅客量    客座率
# 0         False    False     False   False  False  False
# 1         False    False     False   False  False  False
# 2         False    False     False   False  False  False
# 3         False    False     False   False  False  False
# 4         False    False     False   False  False  False
# ..          ...      ...       ...     ...    ...    ...
# 715       False    False     False   False  False  False
# 716       False    False     False   False  False  False
# 717       False    False     False   False  False  False
# 718       False    False     False   False  False  False
# 719       False    False     False   False  False  False
#
# [720 rows x 6 columns]

# %%
 my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 720 entries, 0 to 719
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  720 non-null    int64
#  1   year_id     720 non-null    int64
#  2   month_id    720 non-null    int64
#  3   cty_cd      720 non-null    object
#  4   旅客量         720 non-null    int64
#  5   客座率         720 non-null    float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 33.9+ KB

# %%
#去掉缺省值
my_data.dropna()
# Out:
#      Unnamed: 0  year_id  month_id cty_cd      旅客量       客座率
# 0             0     2016        11    SSS  1537975  0.833608
# 1             1     2015         7    AAA  3603737  0.842056
# 2             2     2016         6    SSS  1405626  0.847005
# 3             3     2015         5    CCC   632758  0.853672
# 4             4     2017         8    HHH   771068  0.895236
# ..          ...      ...       ...    ...      ...       ...
# 715         715     2017         2    UUU   866150  0.830707
# 716         716     2015         4    AAA  3502777  0.835406
# 717         717     2015         3    RRR  1621762  0.831659
# 718         718     2015         2    WWW  2685700  0.801839
# 719         719     2017         2    MMM   749305  0.843860
#
# [720 rows x 6 columns]

# %%
my_data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 715    False
# 716    False
# 717    False
# 718    False
# 719    False
# Length: 720, dtype: bool

# %%
# 查看重复数据
my_data[my_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, year_id, month_id, cty_cd, 旅客量, 客座率]
# Index: []

# %%
#去除重复数据
#my_data = my_data.drop_duplicates()

# %%
my_data.describe()
# Out:
#        Unnamed: 0      year_id    month_id           旅客量         客座率
# count  720.000000   720.000000  720.000000  7.200000e+02  720.000000
# mean   359.500000  2016.000000    6.500000  1.292181e+06    0.846269
# std    207.990384     0.817064    3.454452  8.452066e+05    0.033380
# min      0.000000  2015.000000    1.000000  4.238740e+05    0.720293
# 25%    179.750000  2015.000000    3.750000  7.124585e+05    0.825837
# 50%    359.500000  2016.000000    6.500000  9.107815e+05    0.847067
# 75%    539.250000  2017.000000    9.250000  1.585081e+06    0.868556
# max    719.000000  2017.000000   12.000000  3.998291e+06    0.929070

# %%
d2015_data = my_data[my_data['year_id']==2015]

# %%
d2015_data
# Out:
#      Unnamed: 0  year_id  month_id cty_cd      旅客量       客座率
# 1             1     2015         7    AAA  3603737  0.842056
# 3             3     2015         5    CCC   632758  0.853672
# 5             5     2015         3    MMM   627523  0.834027
# 11           11     2015         3    EEE  2215763  0.895366
# 17           17     2015        10    AAA  3724028  0.842290
# ..          ...      ...       ...    ...      ...       ...
# 710         710     2015         1    HHH   547073  0.868172
# 712         712     2015         2    GGG   974803  0.871934
# 716         716     2015         4    AAA  3502777  0.835406
# 717         717     2015         3    RRR  1621762  0.831659
# 718         718     2015         2    WWW  2685700  0.801839
#
# [240 rows x 6 columns]

# %%
## 分组查找
new_data = my_data.groupby('year_id')['客座率'].mean()

# %%
new_data
# Out:
# year_id
# 2015    0.839188
# 2016    0.844432
# 2017    0.855187
# Name: 客座率, dtype: float64

# %%
my_data.sort_values(by=['year_id', 'month_id'], ascending=[True, False]) #默认升序 可以通过更改 ascending属性 来更改
# Out:
#      Unnamed: 0  year_id  month_id cty_cd      旅客量       客座率
# 21           21     2015        12    JJJ   563325  0.766069
# 44           44     2015        12    AAA  3382515  0.775089
# 138         138     2015        12    EEE  1902949  0.818188
# 193         193     2015        12    RRR  1621484  0.819754
# 273         273     2015        12    NNN   607577  0.788082
# ..          ...      ...       ...    ...      ...       ...
# 541         541     2017         1    CCC   796408  0.874303
# 644         644     2017         1    NNN   744002  0.824329
# 677         677     2017         1    KKK   610945  0.809920
# 680         680     2017         1    SSS  1577063  0.792961
# 694         694     2017         1    ZZZ   797630  0.869608
#
# [720 rows x 6 columns]

# %%
new_data.plot(kind = 'line', figsize = (13, 7),
                 title = '2015-2017年客座率趋势图')
# Out:
# <AxesSubplot:title={'center':'2015-2017年客座率趋势图'}, xlabel='year_id'>

# %% [markdown]
# ## 将处理的表格类型数据存储到excel 中
# ### 并且更改Excel中的样式
# ## 将图像数据以及分析结果存储在 word文档中

# %%
#my_data['有效旅客率']=my_data['客座率']+my_data['旅客量']

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize = (6, 6))
# 设置x轴和y轴的值
x = new_data.index
y = new_data.values
# 绘制折线图

# %%
plt.plot(x, y, linewidth = 2, color = 'r', marker = 'o',
         markerfacecolor = 'blue', markersize = 8)

# %%
plt.xticks(size = 12)
plt.yticks(size = 12)
# 添加x轴和y轴的标签
plt.xlabel('年份', fontdict = {'size': 15})
plt.ylabel('客座率', fontdict = {'size': 12})
# Out:
# Text(0, 0.5, '客座率')

# %%
plt.figure(figsize = (6, 6))
# 设置x轴和y轴的值
x = new_data.index
y = new_data.values
# 绘制折线图
plt.plot(x, y, linewidth = 2, color = 'r', marker = 'o',
         markerfacecolor = 'blue', markersize = 8)
plt.xticks(size = 12)
plt.yticks(size = 12)
# 添加x轴和y轴的标签
plt.xlabel('年份', fontdict = {'size': 15})
plt.ylabel('客座率', fontdict = {'size': 12})
plt.title('各年份客座率变化图', fontsize = 15)
# 保存图形
plt.savefig('样例\市场起飞频度.jpg')
